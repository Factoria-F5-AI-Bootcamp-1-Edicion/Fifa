# %% [markdown]
# # FIFA Dataset EDA
# ___

# %% [markdown]
# ## 1. Importación de librerías.

# %%
# Se importa librerías de análisis de datos y visualización.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 2. Exploración básica de los datos.

# %% [markdown]
# ### Estas son las variables por entrada que contiene este dataset.
# + **ID:** número de identificación del jugador.
# + **Name:** nombre del jugador.
# + **Age:** edad del jugador.
# + **Nationality:** nacionalidad del jugador.
# + **Overall:** Habilidad general de cada jugador.
# + **Potential:** potencial.
# + **Club:** Equipo de fútbol.
# + **Value:** Valor del jugador.
# + **Wage:** Salario
# + **Preferred Foot:** zurdos / diestros.
# + **International Reputation:** reputación internacional del jugador.
# + **Skill Moves:** Habilidad de movimiento.
# + **Position:** Posición en el juego.
# + **Joined:** Entrada al equipo.
# + **Contract Valid Untill:** contrato válido hasta.
# + **Height:** altura.
# + **Weight:** peso.
# + **Release Clause:** Claúsula de liberación.

# %%
#Buena práctica y DataFrame

path_to_data = "./fifa_eda.csv"
df = pd.read_csv(path_to_data)

# %%
# Mapa de calor para ver correlación
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(df.corr(), mask=mask, vmax=1., vmin=-1., center=0,
square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Con el mapa de calor vemos que hay una correlación muy fuerte entre la clausula de contrato y el valor de mercado .

# %% [markdown]
# ### Limpieza de datos
# + Limpiamos los valores NaN de Club, Value, International Reputation, Skill Moves, Contract Valid Until

# %%
# hacemos limpieza de valoreS NaN
df= df.dropna()

# %%
#Ver las primeras cinco entradas.
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
# 4                       4.0          4.0      RCM    2015
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0
# 3           2020-01-01  6.333333   168.0        138600.0
# 4           2023-01-01  5.916667   154.0        196400.0

# %%
# Se muestran las últimas entradas.
df.tail()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18202          2.0       CM    2017           2019-01-01  5.750000   134.0
# 18203          2.0       ST    2018           2020-01-01  6.250000   170.0
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18202           143.0
# 18203           113.0
# 18204           165.0
# 18205           143.0
# 18206           165.0

# %%
# Información del dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17907 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17907 non-null  int64
#  1   Name                      17907 non-null  object
#  2   Age                       17907 non-null  int64
#  3   Nationality               17907 non-null  object
#  4   Overall                   17907 non-null  int64
#  5   Potential                 17907 non-null  int64
#  6   Club                      17907 non-null  object
#  7   Value                     17907 non-null  float64
#  8   Wage                      17907 non-null  float64
#  9   Preferred Foot            17907 non-null  object
#  10  International Reputation  17907 non-null  float64
#  11  Skill Moves               17907 non-null  float64
#  12  Position                  17907 non-null  object
#  13  Joined                    17907 non-null  int64
#  14  Contract Valid Until      17907 non-null  object
#  15  Height                    17907 non-null  float64
#  16  Weight                    17907 non-null  float64
#  17  Release Clause            17907 non-null  float64
# dtypes: float64(7), int64(5), object(6)
# memory usage: 2.6+ MB

# %%
#Cantidad de entradas y columnas. 
df.shape
# Out:
# (17907, 18)

# %% [markdown]
# Se observa:
# + 18 columnas.
# + 18207 entradas.

# %%
# Nombre de las columnas:
df.columns.values
# Out:
# array(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until',
#        'Height', 'Weight', 'Release Clause'], dtype=object)

# %%
#Se verifica si faltan datos.
df.isnull().sum(axis = 0)
# Out:
# ID                          0
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Club                        0
# Value                       0
# Wage                        0
# Preferred Foot              0
# International Reputation    0
# Skill Moves                 0
# Position                    0
# Joined                      0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# Release Clause              0
# dtype: int64

# %% [markdown]
# Se observa:
# + Faltan datos en Contract Valid Until, Value, Club, International Reputation y Skill Moves.
# + La falta de datos no es significativa en relación a las entradas.

# %%
# Identificación de variables con las que vamos a trabajar :
categoricas = ["Name" , "Nationality", "Club", "Preferred Foot", "Position", ]
numericas = ["Age", "Potential", "Value", "Wage", "Internation Reputation", "Skill Moves", "Height"]

# %%
df.isnull().sum(axis = 0)
# Out:
# ID                          0
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Club                        0
# Value                       0
# Wage                        0
# Preferred Foot              0
# International Reputation    0
# Skill Moves                 0
# Position                    0
# Joined                      0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# Release Clause              0
# dtype: int64

# %%
# Información de las variables numéricas.
df.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   17907.000000  17907.000000  17907.000000  17907.000000   17907.000000
# mean   214286.938795     25.095605     66.239571     71.335232    2450.132909
# std     29885.734201      4.660388      6.926818      6.137251    5633.206685
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200257.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221710.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236512.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  17907.000000              17907.000000  17907.000000  17907.000000
# mean       9.887753                  1.113699      2.363042   2016.429553
# std       22.148656                  0.395193      0.756256      2.027399
# min        1.000000                  1.000000      1.000000   1991.000000
# 25%        1.000000                  1.000000      2.000000   2016.000000
# 50%        3.000000                  1.000000      2.000000   2017.000000
# 75%        9.000000                  1.000000      3.000000   2018.000000
# max      565.000000                  5.000000      5.000000   2018.000000
#
#              Height        Weight  Release Clause
# count  17907.000000  17907.000000    17907.000000
# mean       5.946711    165.964316     4585.060974
# std        0.220812     15.602524    10719.096361
# min        5.083333    110.000000       13.000000
# 25%        5.750000    154.000000      563.000000
# 50%        5.916667    165.000000     1300.000000
# 75%        6.083333    176.000000     4585.060806
# max        6.750000    243.000000   228100.000000

# %%
# Se comprueba la desviación, la media, moda, mediana, cuartiles.
df["Weight"].plot(kind = 'hist')
plt.show()

# %% [markdown]
# Comprobando las desviaciones, la variable Weight es la que está en el límite de primera desviación estándar.

# %%
# Distribución atípica en la campana de Gauss.
df["Value"].plot(kind = 'hist')
plt.show()

# %% [markdown]
# Se observa que hay una desviación estándar cuyo datos pueden ser sesgados.

# %%
sns.scatterplot(data=df, x="Value", y="International Reputation", hue="Age")
# Out:
# <AxesSubplot:xlabel='Value', ylabel='International Reputation'>

# %%
#sns.scatterplot(x="Value", y=, data=df)
#plt.xticks(rotation=90)
#plt.grid(axis='x')
#plt.grid(axis='y')
#plt.show()

# %%
#Revisión.
df.boxplot( column =['Value'], grid = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Identificamos outliers en Value.

# %%
#Información por columna, moda.
for col in categoricas:
    print(f"Column name: {col}")
    print(df[col].value_counts())
    print()
# Out:
# Column name: Name
# J. Rodríguez    11
# Paulinho         8
# J. Williams      7
# Felipe           6
# R. Williams      6
#                 ..
# Hugo Basto       1
# Kanu             1
# C. Arango        1
# M. Karl          1
# G. Nugent        1
# Name: Name, Length: 16913, dtype: int64
#
# Column name: Nationality
# England      1655
# Germany      1195
# Spain        1071
# Argentina     935
# France        910
#              ...
# Guam            1
# Fiji            1
# Liberia         1
# Mauritius       1
# Botswana        1
# Name: Nationality, Length: 163, dtype: int64
#
# Column name: Club
# FC Barcelona               33
# Southampton                33
# Cardiff City               33
# TSG 1899 Hoffenheim        33
# Wolverhampton Wanderers    33
#                            ..
# Vitória                    20
# Bahia                      20
# Sligo Rovers               19
# Limerick FC                19
# Derry City                 18
# Name: Club, Length: 651, dtype: int64
#
# Column name: Preferred Foot
# Right    13748
# Left      4159
# Name: Preferred Foot, dtype: int64
#
# Column name: Position
# ST     2130
# GK     1989
# CB     1751
# CM     1377
# LB     1304
# RB     1268
# RM     1114
# LM     1086
# CAM     946
# CDM     936
# RCB     652
# LCB     635
# LCM     389
# RCM     387
# LW      374
# RW      365
# RDM     246
# LDM     239
# LS      206
# RS      201
# RWB      87
# LWB      78
# CF       74
# LAM      21
# RAM      21
# RF       16
# LF       15
# Name: Position, dtype: int64

# %% [markdown]
# Se observa:
# + En la columna "name" hay nombres repetidos por lo que se sospecha de que haya datos duplicados

# %%
# Se verifica si hay datos duplicados. 
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Length: 17907, dtype: bool

# %% [markdown]
# Se observa:
# + No hay datos duplicados por lo que se supone que pueden ser homónimos o falta información en "name".

# %%
# Se reducen variables que no se tendrán en cuenta al no estar especificadas.
df.drop(["ID","Overall","Contract Valid Until", "Joined", "Height", "Weight", "Release Clause"], axis = 1, inplace = True)

# %%
# Se comprueba la eliminación de variables.
df.shape
# Out:
# (17907, 11)

# %%
# Se muestran las columnas con las que se van a trabajar.
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Potential', 'Club', 'Value', 'Wage',
#        'Preferred Foot', 'International Reputation', 'Skill Moves',
#        'Position'],
#       dtype='object')

# %%
#mapa de calor sin Overall
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(df.corr(), mask=mask, vmax=1., vmin=-1., center=0,
square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Hemos eliminado variables con mayor correlación , para evitar la colinealidad y que los datos sean claros.
# Además seguimos demostrando que hay una gran correlación entre salario y valor de mercado.

# %%
# Buscamos a los jugadores más jóvenes. Con ".loc" podemos seleccionar variables, con .min() encontramos los valores más bajos.
df_jovenes = df.loc[df['Age'] == df['Age'].min()]
df_jovenes
# Out:
#                   Name  Age          Nationality  Potential  \
# 11457      W. Geubbels   16               France         86
# 11732         A. Taoui   16               France         75
# 12496   Pelayo Morilla   16                Spain         81
# 12828         Guerrero   16                Spain         76
# 13293      H. Massengo   16               France         75
# 13567   Y. Verschaeren   16              Belgium         83
# 15363        Y. Roemer   16          Netherlands         75
# 15746      Y. Begraoui   16               France         81
# 15793         J. Lahne   16               Sweden         77
# 16081      J. Italiano   16            Australia         79
# 16254        S. Steijn   16          Netherlands         72
# 16418      J. Kitolano   16               Norway         75
# 16544       D. Adshead   16              England         77
# 16927        B. Nygren   16               Sweden         73
# 17091         A. Doğan   16               Turkey         71
# 17115       C. Bassett   16        United States         77
# 17175         B. Mumba   16              England         80
# 17177         R. Gómez   16            Argentina         76
# 17200     H. Andersson   16               Sweden         70
# 17263  P. Samiec-Talar   16               Poland         73
# 17354      L. D'Arrigo   16            Australia         71
# 17712         K. Broda   16               Poland         74
# 17743        J. Olstad   16               Norway         69
# 17751         E. Ceide   16               Norway         75
# 17753         B. Waine   16          New Zealand         66
# 17757         L. Smyth   16     Northern Ireland         73
# 17776   M. Köstenbauer   16              Austria         74
# 17808     A. Mahlonoko   16         South Africa         71
# 17841   F. Tauchhammer   16              Austria         71
# 17881         R. Hauge   16               Norway         67
# 17887         M. Tilio   16            Australia         69
# 17921       J. Rowland   16              England         66
# 17976        M. Larsen   16              Denmark         71
# 18003     J. Imbrechts   16               Sweden         72
# 18018      B. O'Gorman   16  Republic of Ireland         69
# 18044          K. Lara   16             Colombia         74
# 18106        J. Cleary   16  Republic of Ireland         72
# 18124     G. Hollywood   16  Republic of Ireland         67
# 18162     T. Gundelund   16              Denmark         66
# 18166         N. Ayéva   16               Sweden         72
# 18204        B. Worman   16              England         67
# 18206        G. Nugent   16              England         66
#
#                            Club   Value  Wage Preferred Foot  \
# 11457                 AS Monaco  1000.0   5.0          Right
# 11732    Toulouse Football Club   700.0   3.0           Left
# 12496    Real Sporting de Gijón   725.0   1.0           Left
# 12828       CF Rayo Majadahonda   625.0   1.0           Left
# 13293                 AS Monaco   450.0   2.0          Right
# 13567            RSC Anderlecht   650.0   1.0          Right
# 15363                 VVV-Venlo   300.0   1.0          Right
# 15746                AJ Auxerre   350.0   1.0          Right
# 15793         IF Brommapojkarna   300.0   1.0          Right
# 16081               Perth Glory   280.0   1.0          Right
# 16254                 VVV-Venlo   250.0   1.0          Right
# 16418                   Odds BK   200.0   1.0          Right
# 16544                  Rochdale   200.0   1.0          Right
# 16927              IFK Göteborg   180.0   1.0           Left
# 17091               Kayserispor   160.0   1.0          Right
# 17115           Colorado Rapids   180.0   1.0          Right
# 17175                Sunderland   190.0   1.0          Right
# 17177       Belgrano de Córdoba   190.0   1.0          Right
# 17200                 Örebro SK   160.0   1.0          Right
# 17263             Śląsk Wrocław   180.0   1.0          Right
# 17354           Adelaide United   130.0   1.0          Right
# 17712              Wisła Kraków   110.0   1.0          Right
# 17743           Sarpsborg 08 FF   100.0   1.0          Right
# 17751              Rosenborg BK   110.0   1.0          Right
# 17753        Wellington Phoenix   100.0   1.0          Right
# 17757                 Stevenage   110.0   1.0          Right
# 17776  FC Admira Wacker Mödling    90.0   1.0          Right
# 17808           Orlando Pirates   100.0   1.0          Right
# 17841            Wolfsberger AC    90.0   1.0          Right
# 17881             FK Bodø/Glimt   100.0   1.0          Right
# 17887                 Sydney FC   100.0   1.0           Left
# 17921                Shrewsbury    70.0   1.0          Right
# 17976                Esbjerg fB    70.0   1.0          Right
# 18003     Sporting de Charleroi    70.0   1.0          Right
# 18018            Bray Wanderers    60.0   1.0          Right
# 18044            Atlético Huila    60.0   1.0          Right
# 18106               Bohemian FC    50.0   1.0          Right
# 18124            Bray Wanderers    60.0   1.0          Right
# 18162            Vejle Boldklub    50.0   1.0          Right
# 18166                 Örebro SK    70.0   1.0          Right
# 18204          Cambridge United    60.0   1.0          Right
# 18206           Tranmere Rovers    60.0   1.0          Right
#
#        International Reputation  Skill Moves Position
# 11457                       1.0          3.0       ST
# 11732                       1.0          3.0       ST
# 12496                       1.0          3.0       RM
# 12828                       1.0          3.0       CM
# 13293                       1.0          2.0      CDM
# 13567                       1.0          3.0      CAM
# 15363                       1.0          3.0       ST
# 15746                       1.0          2.0       ST
# 15793                       1.0          2.0       ST
# 16081                       1.0          3.0       LM
# 16254                       1.0          3.0      CAM
# 16418                       1.0          2.0      LCM
# 16544                       1.0          2.0       CM
# 16927                       1.0          2.0       ST
# 17091                       1.0          2.0       CB
# 17115                       1.0          2.0      CDM
# 17175                       1.0          2.0       CM
# 17177                       1.0          2.0       RM
# 17200                       1.0          2.0       CB
# 17263                       1.0          2.0       ST
# 17354                       1.0          2.0      CAM
# 17712                       1.0          1.0       GK
# 17743                       1.0          2.0       ST
# 17751                       1.0          2.0       RW
# 17753                       1.0          2.0       ST
# 17757                       1.0          2.0       ST
# 17776                       1.0          1.0       GK
# 17808                       1.0          2.0      CAM
# 17841                       1.0          2.0       RB
# 17881                       1.0          2.0       CM
# 17887                       1.0          2.0      CAM
# 17921                       1.0          2.0      CAM
# 17976                       1.0          2.0       CM
# 18003                       1.0          1.0       GK
# 18018                       1.0          2.0       RM
# 18044                       1.0          2.0       RB
# 18106                       1.0          1.0       GK
# 18124                       1.0          2.0       CM
# 18162                       1.0          2.0      RWB
# 18166                       1.0          2.0       ST
# 18204                       1.0          2.0       ST
# 18206                       1.0          2.0       CM

# %% [markdown]
# Se observa:
# + Los jugadores más jóvenes son de 16 años.
#
# + El nivel de reputación de todos es de 1.0.
# + Se unieron entre los años 2017 y 2018.

# %%
# Jugadores más jóvenes y nacionalidad.
Variable_edad=df.loc[df['Age'] == df ['Age'].min()][['Name','Age','Nationality']]
Variable_edad
# Out:
#                   Name  Age          Nationality
# 11457      W. Geubbels   16               France
# 11732         A. Taoui   16               France
# 12496   Pelayo Morilla   16                Spain
# 12828         Guerrero   16                Spain
# 13293      H. Massengo   16               France
# 13567   Y. Verschaeren   16              Belgium
# 15363        Y. Roemer   16          Netherlands
# 15746      Y. Begraoui   16               France
# 15793         J. Lahne   16               Sweden
# 16081      J. Italiano   16            Australia
# 16254        S. Steijn   16          Netherlands
# 16418      J. Kitolano   16               Norway
# 16544       D. Adshead   16              England
# 16927        B. Nygren   16               Sweden
# 17091         A. Doğan   16               Turkey
# 17115       C. Bassett   16        United States
# 17175         B. Mumba   16              England
# 17177         R. Gómez   16            Argentina
# 17200     H. Andersson   16               Sweden
# 17263  P. Samiec-Talar   16               Poland
# 17354      L. D'Arrigo   16            Australia
# 17712         K. Broda   16               Poland
# 17743        J. Olstad   16               Norway
# 17751         E. Ceide   16               Norway
# 17753         B. Waine   16          New Zealand
# 17757         L. Smyth   16     Northern Ireland
# 17776   M. Köstenbauer   16              Austria
# 17808     A. Mahlonoko   16         South Africa
# 17841   F. Tauchhammer   16              Austria
# 17881         R. Hauge   16               Norway
# 17887         M. Tilio   16            Australia
# 17921       J. Rowland   16              England
# 17976        M. Larsen   16              Denmark
# 18003     J. Imbrechts   16               Sweden
# 18018      B. O'Gorman   16  Republic of Ireland
# 18044          K. Lara   16             Colombia
# 18106        J. Cleary   16  Republic of Ireland
# 18124     G. Hollywood   16  Republic of Ireland
# 18162     T. Gundelund   16              Denmark
# 18166         N. Ayéva   16               Sweden
# 18204        B. Worman   16              England
# 18206        G. Nugent   16              England

# %% [markdown]
# ## 3. Gráficos.

# %% [markdown]
# ### Los gráficos están basados en la nueva variable "contrato_vigente" que son los jugadores que poseen contrato vigente de 2023 en adelante.

# %% [markdown]
# La mejor marca de goles la tiene la nacionalidad belga.

# %%
# Comparamos la nacionalidad con el potencial.
sns.catplot(x="Nationality", y="Potential", data=df, kind="bar", aspect=4, height=5)
plt.xticks(rotation=90)
plt.grid(axis='x')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Se observa en la gráfica que están por encima de 50 pocas nacionalidades, de ellas la que más destaca es Cabo verde, de puede deber a que allía hay mejores entrenadores para los futbolistas o su condición física sea más favorable.

# %%
sns.catplot(x="Nationality", y="Age", data=df, kind="bar", aspect=2, height=10)
plt.xticks(rotation=90)
plt.grid(axis='x')
plt.grid(axis='y')
plt.show()

# %%
sns.scatterplot(data=barcelona, x="Age", y="Potential", hue="Nationality")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 sns.scatterplot(data=barcelona, x="Age", y="Potential", hue="Nationality")
#
# NameError: name 'barcelona' is not defined

# %% [markdown]
# ### Día 2

# %%
# Correlaciones con Value mayor de 5000.
df[df["Value"]>5000].corr()

# %% [markdown]
# Se observa correlaciones más altas entre Value mayor de 500 y Overall.

# %%
# Mapa de calor
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(df.corr(), mask=mask, vmax=1., vmin=-1., center=0,
square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

# %%
df_map= df[["Age","Potential", "Value", "Wage", "International Reputation"]]

# %% [markdown]
# Hipótesis:
# + Overall y jugador barato.
# + País con mas jugadores. Ok
# + ¿Cuántos zurdos/Diestros? ESPERAR A UMIT
# + relación si peso y altura , influye en la posición que juegan
# + relación de edad del futbolista y lo que cobra. OK

# %%
# 5 Países con más jugadores
df['Nationality'].value_counts().head(5)

# %%
plt.figure(figsize = (10,6))
df['Nationality'].value_counts().head(15).plot.bar()
plt.show()

# %% [markdown]
# Con el análisis visual observamos que el país que más jugadores tiene es Inglaterra con más de 1600 jugadores, puesto que la liga inglesa es una de las más potente.
# Hay una gran diferencia con Alemania que le sigue con 400 jugadores menos.

# %%
# Los clubs que tienen más jugadores
df['Club'].value_counts().sort_values(ascending = False)

# %%
# Los clubes que tienen menos jugadores
df['Club'].value_counts().sort_values(ascending = True)

# %% [markdown]
# El promedio de los clubs con más jugadores cuenta con 33

# %%
# PRueba 2 pedir ayuda float
#var1 = pd.DataFrame(range(5), columns=['Value'])
#var1.a = df['Value'].astype('int64')
#var1

# %%
# Pedir ayuda Error en float
#temp2 = df[~df["Value"] & (df["Value"] >= 51000.0) & (df["Value"] < 78000.0)]
#temp2

# %%
# Comparación edad y salario.
sns.scatterplot(x="Age", y="Wage", data=df)

# %% [markdown]
# La edad se comprende desde 16 a 45 años. El rango de acumulación está entre 27 y 30 años, en relación al salario.
# Se aprecian outliers en la edad de 32 a 34 años, son las 5 personas con más salario.
# Creemos que estas personas que sobresalen porque son los mejores jugadores.

# %%
#la mayoría de las posiciones de la lista
df['Position'].value_counts()

# %% [markdown]
# Esto nos muestra la cantidad de los jugadores delanteros,medio centros , defensa y porteros ...
# Hay más jugadores que juegan en la posición de delantero (2130) y en segundo puesto sorprendentemente estan los porteros(1989) , frente a los delanteros izquierdos que estan en último puesto ya que solo hay 15.
#
# <img src=
# "https://www.fifplay.com/img/public/position-lf.jpg" width="300" height="300">

# %%
#comprobamos si hay mas jugadores diestros o zurdos
df['Preferred Foot'].value_counts()

# %%
sns.countplot(x='Preferred Foot', data=df)

# %% [markdown]
# Con esto demostramos que hay más jugadores diestros.

# %%
sns.scatterplot(data=df, x="Preferred Foot", y="Wage", hue="Preferred Foot" )

# %% [markdown]
# Con esta gráfica podemos ver que el salario de jugadores zurdos estan muy bien valorado , y suponemos que es porque se encuentran en menos cantidad .
